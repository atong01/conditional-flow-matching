# %%
# %load_ext autoreload
# %autoreload 2
import os

import matplotlib.pyplot as plt
import torch
import torchdiffeq
import torchsde
from torchdyn.core import NeuralODE
from torchvision import datasets, transforms
from torchvision.transforms import ToPILImage
from torchvision.utils import make_grid
from tqdm import tqdm

from torchcfm.conditional_flow_matching import *
from torchcfm.models.unet import UNetModel

savedir = "models/mnist"
os.makedirs(savedir, exist_ok=True)
# Out:
# /home/mila/a/alexander.tong/.conda/envs/trajectory-inference/lib/python3.10/site-packages/lightning_utilities/core/imports.py:93: UserWarning: Unbuilt egg for MIOFlow [unknown version] (/home/mila/a/alexander.tong/MIOFlow)
#   pkg_resources.require(self.requirement)

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
batch_size = 128
n_epochs = 3

trainset = datasets.MNIST(
    "../data",
    train=True,
    download=True,
    transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]),
)

train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, drop_last=True
)

# %%
#################################
#    Class Conditional CFM
#################################

sigma = 0.0
model = UNetModel(dim=(1, 28, 28), num_channels=32, num_res_blocks=1, num_classes=10).to(device)
optimizer = torch.optim.Adam(model.parameters())
FM = ConditionalFlowMatcher(sigma=sigma)
node = NeuralODE(model, solver="dopri5", sensitivity="adjoint", atol=1e-4, rtol=1e-4)

# %%
for epoch in range(n_epochs):
    for i, data in enumerate(train_loader):
        optimizer.zero_grad()
        x1 = data[0].to(device)
        y = data[1].to(device)
        x0 = torch.randn_like(x1)
        t, xt, ut = FM.sample_location_and_conditional_flow(x0, x1)
        vt = model(t, xt, y)
        loss = torch.mean((vt - ut) ** 2)
        loss.backward()
        optimizer.step()
        print(f"epoch: {epoch}, steps: {i}, loss: {loss.item():.4}", end="\r")
# Out:
# epoch: 2, steps: 467, loss: 0.1683

# %%
USE_TORCH_DIFFEQ = True
l = torch.arange(10).repeat(10).to(device)
with torch.no_grad():
    if USE_TORCH_DIFFEQ:
        traj = torchdiffeq.odeint(
            lambda t, x: model.forward(t, x, l),
            torch.randn(100, 1, 28, 28).to(device),
            torch.linspace(0, 1, 2).to(device),
            atol=1e-4,
            rtol=1e-4,
            method="dopri5",
        )
    else:
        traj = node.trajectory(
            torch.randn(100, 1, 28, 28).to(device),
            t_span=torch.linspace(0, 1, 2).to(device),
        )
grid = make_grid(
    traj[-1, :100].view([-1, 1, 28, 28]).clip(-1, 1), value_range=(-1, 1), padding=0, nrow=10
)
img = ToPILImage()(grid)
plt.imshow(img)
plt.show()

# %%
#################################
#            OT-CFM
#################################

sigma = 0.0
model = UNetModel(dim=(1, 28, 28), num_channels=32, num_res_blocks=1, num_classes=10).to(device)
optimizer = torch.optim.Adam(model.parameters())
FM = ExactOptimalTransportConditionalFlowMatcher(sigma=sigma)
node = NeuralODE(model, solver="dopri5", sensitivity="adjoint", atol=1e-4, rtol=1e-4)

# %%
for epoch in range(n_epochs):
    for i, data in enumerate(train_loader):
        optimizer.zero_grad()
        x1 = data[0].to(device)
        y = data[1].to(device)
        x0 = torch.randn_like(x1)
        t, xt, ut, y1 = FM.sample_location_and_conditional_flow(x0, x1, y1=y)
        vt = model(t, xt, y1)
        loss = torch.mean((vt - ut) ** 2)
        loss.backward()
        optimizer.step()
        print(f"epoch: {epoch}, steps: {i}, loss: {loss.item():.4}", end="\r")
# Out:
# epoch: 2, steps: 467, loss: 0.1279

# %%
USE_TORCH_DIFFEQ = True
l = torch.arange(10).repeat(10).to(device)
with torch.no_grad():
    if USE_TORCH_DIFFEQ:
        traj = torchdiffeq.odeint(
            lambda t, x: model.forward(t, x, l),
            torch.randn(100, 1, 28, 28).to(device),
            torch.linspace(0, 1, 2).to(device),
            atol=1e-4,
            rtol=1e-4,
            method="dopri5",
        )
    else:
        traj = node.trajectory(
            torch.randn(100, 1, 28, 28).to(device),
            t_span=torch.linspace(0, 1, 2).to(device),
        )
grid = make_grid(
    traj[-1, :100].view([-1, 1, 28, 28]).clip(-1, 1), value_range=(-1, 1), padding=0, nrow=10
)
img = ToPILImage()(grid)
plt.imshow(img)
plt.show()

# %%
#################################
#            SF2M
#################################
batch_size = 128
n_epochs = 10
sigma = 0.1

# We note that with a little bit of effort these two networks can be combined to a single network with two prediction heads
# We leave it this way for simplicity in the notebook, but encourage you to consider supplying the `learn_sigma=True` parameter
# to the UNetModel, which outputs a shape (batch, 2, 28, 28), and can be used to increase efficiency.
model = UNetModel(dim=(1, 28, 28), num_channels=32, num_res_blocks=1, num_classes=10).to(device)
score_model = UNetModel(dim=(1, 28, 28), num_channels=32, num_res_blocks=1, num_classes=10).to(
    device
)

optimizer = torch.optim.Adam(list(model.parameters()) + list(score_model.parameters()))
FM = SchrodingerBridgeConditionalFlowMatcher(sigma=sigma)
node = NeuralODE(model, solver="dopri5", sensitivity="adjoint", atol=1e-4, rtol=1e-4)

# %%
for epoch in range(n_epochs):
    for i, data in tqdm(enumerate(train_loader)):
        optimizer.zero_grad()
        x1 = data[0].to(device)
        y = data[1].to(device)
        x0 = torch.randn_like(x1)
        t, xt, ut, y1, eps = FM.sample_location_and_conditional_flow(
            x0, x1, y1=y, return_noise=True
        )
        lambda_t = FM.compute_lambda(t)
        vt = model(t, xt, y1)
        st = score_model(t, xt, y1)
        flow_loss = torch.mean((vt - ut) ** 2)
        score_loss = torch.mean((lambda_t[:, None, None, None] * st + eps) ** 2)
        loss = flow_loss + score_loss
        loss.backward()
        optimizer.step()
# Out:
# 468it [01:48,  4.31it/s]
# 468it [01:48,  4.31it/s]
# 468it [01:48,  4.31it/s]
# 324it [01:14,  4.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 10
#       8 lambda_t = FM.compute_lambda(t)
#       9 vt = model(t, xt, y1)
# ---> 10 st = score_model(t, xt, y1)
#      11 flow_loss = torch.mean((vt - ut) ** 2)
#      12 score_loss = torch.mean((lambda_t[:, None, None, None] * st + eps) ** 2)
#
# File ~/.conda/envs/trajectory-inference/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/conditional-flow-matching/torchcfm/models/unet/unet.py:618, in UNetModel.forward(self, t, x, y)
#     615     timesteps = timesteps.repeat(x.shape[0])
#     617 hs = []
# --> 618 emb = self.time_embed(timestep_embedding(timesteps, self.model_channels))
#     620 if self.num_classes is not None:
#     621     assert y.shape == (x.shape[0],)
#
# File ~/conditional-flow-matching/torchcfm/models/unet/nn.py:96, in timestep_embedding(timesteps, dim, max_period)
#      88 """Create sinusoidal timestep embeddings.
#      89
#      90 :param timesteps: a 1-D Tensor of N indices, one per batch element. These may be fractional.
#    (...)
#      93 :return: an [N x dim] Tensor of positional embeddings.
#      94 """
#      95 half = dim // 2
# ---> 96 freqs = th.exp(
#      97     -math.log(max_period) * th.arange(start=0, end=half, dtype=th.float32) / half
#      98 ).to(device=timesteps.device)
#      99 args = timesteps[:, None].float() * freqs[None]
#     100 embedding = th.cat([th.cos(args), th.sin(args)], dim=-1)
#
# KeyboardInterrupt:

# %%
node = NeuralODE(model, solver="euler", sensitivity="adjoint", atol=1e-4, rtol=1e-4)
# Evaluate the ODE
with torch.no_grad():
    if USE_TORCH_DIFFEQ:
        traj = torchdiffeq.odeint(
            lambda t, x: model.forward(t, x, l),
            torch.randn(100, 1, 28, 28).to(device),
            torch.linspace(0, 1, 2).to(device),
            atol=1e-4,
            rtol=1e-4,
            method="dopri5",
        )
    else:
        traj = node.trajectory(
            torch.randn(100, 1, 28, 28).to(device),
            t_span=torch.linspace(0, 1, 2).to(device),
        )
grid = make_grid(
    traj[-1, :100].view([-1, 1, 28, 28]).clip(-1, 1), value_range=(-1, 1), padding=0, nrow=10
)
img = ToPILImage()(grid)
plt.imshow(img)

# %%
# follows example from https://github.com/google-research/torchsde/blob/master/examples/cont_ddpm.py


class SDE(torch.nn.Module):
    noise_type = "diagonal"
    sde_type = "ito"

    def __init__(self, ode_drift, score, input_size=(1, 28, 28), labels=None, reverse=False):
        super().__init__()
        self.drift = ode_drift
        self.score = score
        self.reverse = reverse
        self.labels = labels

    # Drift
    def f(self, t, y):
        l = self.labels
        y = y.view(-1, 1, 28, 28)
        if self.reverse:
            t = 1 - t
            return -self.drift(t, y, l) + self.score(t, y, l)
        return self.drift(t, y, l).flatten(start_dim=1) - self.score(t, y, l).flatten(start_dim=1)

    # Diffusion
    def g(self, t, y):
        y = y.view(-1, 1, 28, 28)
        return (torch.ones_like(t) * torch.ones_like(y)).flatten(start_dim=1) * sigma

# %%
# from torchcfm.utils import SDE
sde = SDE(model, score_model, labels=torch.arange(10).repeat(10).to(device))
with torch.no_grad():
    sde_traj = torchsde.sdeint(
        sde,
        # x0.view(x0.size(0), -1),
        torch.randn(100, 1 * 28 * 28).to(device),
        ts=torch.linspace(0, 1, 2).to(device),
        dt=0.01,
    )

# %%
grid = make_grid(
    sde_traj[-1, :100].view([-1, 1, 28, 28]).clip(-1, 1), value_range=(-1, 1), padding=0, nrow=10
)
img = ToPILImage()(grid)
plt.imshow(img)
